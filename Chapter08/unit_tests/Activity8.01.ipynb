# %%
import sqlite3 

import pandas as pd 

conn = sqlite3.connect("../petsdb.db") 

person = pd.read_csv("../persons.csv") 

person.to_sql("persons", conn, if_exists="replace") 

pets = pd.read_csv("../pets.csv") 

pets.to_sql("pets", conn, if_exists="replace") 

conn.close()

# %%
def test_exercise_1(x) -> bool:
    import sqlite3 
    conn = sqlite3.connect("petsdb.db") 
    return conn == x

# %%
def test_exercise_2(x) -> bool: 
    return "True" == x

# %%
def test_exercise_3(x) -> bool: 
    return "True" == x

# %%
def test_exercise_3(x) -> bool: 
    conn = sqlite3.connect("petsdb.db") 
    c = conn.cursor() 
    return c == x
