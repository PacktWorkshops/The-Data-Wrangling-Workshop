# %%
from math import cos, pi
ys = [cos(i*(pi/4)) for i in range(50)]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
plt.plot(ys)

# %%
ys[4] = ys[4] + 5.0
ys[20] = ys[20] + 8.0

# %%
plt.plot(ys)

# %%
plt.boxplot(ys)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1982d57fd08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1982d585c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1982d57f248>],
#  'medians': [<matplotlib.lines.Line2D at 0x1982d58ac08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1982d58ad08>],
#  'means': []}
