# %%
def test_exercise_1(x) -> bool:
    import sys
    if "pandas" in sys.modules:
        return False
    else:
        return True

# %%
def test_exercise_2(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    education_data_link="http://data.un.org/_Docs/SYB/CSV/SYB61_T07_Education.csv" 
    df = pd.read_csv(education_data_link)
    return df == x

# %%
def test_exercise_3(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    education_data_link="http://data.un.org/_Docs/SYB/CSV/SYB61_T07_Education.csv" 
    df = pd.read_csv(education_data_link)
    return df.head() == x

# %%
def test_exercise_4(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df = pd.read_csv(education_data_link,skiprows=1)
    return df == x

# %%
def test_exercise_5(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df = pd.read_csv(education_data_link,skiprows=1)
    return df.head() == x

# %%
def test_exercise_6(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    return df2 == x

# %%
def test_exercise_7(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    return df2 == x

# %%
def test_exercise_9(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    return df2['Footnotes'].unique() == x

# %%
def test_exercise_10(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    return type(df2['Enrollments (Thousands)'][0]) == x

# %%
def test_exercise_13(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df2 == x

# %%
def test_exercise_14(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df2[df2['Data']=='Students enrolled in primary education (thousands)'] == x

# %%
def test_exercise_15(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df2[df2['Data']=='Students enrolled in secondary education (thousands)'] == x

# %%
def test_exercise_15(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df2[df2['Data']=='Students enrolled in secondary education (thousands)'] == x

# %%
def test_exercise_15(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df2[df2['Data']=='Students enrolled in tertiary education (thousands)'] == x

# %%
def test_exercise_16(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df_primary[df_primary['Region/Country/Area']=='India'] == x

# %%
def test_exercise_16(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    df2['Enrollments (Thousands)']=df2['Enrollments (Thousands)'].apply(to_numeric) 
    return df_primary[df_primary['Region/Country/Area']=='United States of America'] == x

# %%
def test_exercise_27(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    missing_years = [y for y in range(2004,2010)]+[y for y in range(2011,2014)] 
    return missing_years == x

# %%
def test_exercise_28(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    dict_missing = {'Region/Country/Area':['India']*9,'Year':missing_years, 
                'Data':'Students enrolled in primary education (thousands)'*9, 
                'Enrollments (Thousands)':[np.nan]*9,'Footnotes':[np.nan]*9} 
    return dict_missing == x

# %%
def test_exercise_28(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    import warnings 
    warnings.filterwarnings('ignore')
    df1 = pd.read_csv(education_data_link,skiprows=1)
    df2 = df1.drop(['Region/Country/Area','Source'],axis=1)
    df2.columns=['Region/Country/Area','Year','Data','Enrollments (Thousands)','Footnotes'] 
    def to_numeric(val): 
        if ',' not in str(val): 
            result = float(val) 
        else: 
            val=str(val) 
            val=''.join(str(val).split(',')) 
            result=float(val) 
        return result
    dict_missing = {'Region/Country/Area':['India']*9,'Year':missing_years, 
                'Data':'Students enrolled in primary education (thousands)'*9, 
                'Enrollments (Thousands)':[np.nan]*9,'Footnotes':[np.nan]*9} 
    df_missing = pd.DataFrame(data=dict_missing)
    return df_missing == x
