# %%
def test_exercise_88_1(x) -> bool:
    import requests 
    import xml.etree.ElementTree as ET
    from bs4 import BeautifulSoup 
    wiki_home = "https://en.wikipedia.org/wiki/Main_Page"
    response = requests.get(wiki_home)
    def decode_content(r,encoding): 
        return (r.content.decode(encoding)) 
    contents = decode_content(response,encoding_check(response)) 
    soup = BeautifulSoup(contents, 'html.parser')
    txt_dump=soup.text
    text_list=[] #Empty list 
        for d in soup.find_all('div'): 
            if (d.get('id')=='mp-otd'): 
                for i in d.find_all('ul'): 
                    text_list.append(i.text)
    data = ''' 
<person> 
  <name>Dave</name> 
  <surname>Piccardo</surname> 
  <phone type="intl"> 
     +1 742 101 4456 
   </phone> 
   <email hide="yes"> 
   dave.p@gmail.com</email> 
</person>''' 
    tree = ET.fromstring(data)
    return tree.find('name').text == x

# %%
def test_exercise_88_2(x) -> bool:
    import requests 
    import xml.etree.ElementTree as ET
    from bs4 import BeautifulSoup 
    wiki_home = "https://en.wikipedia.org/wiki/Main_Page"
    response = requests.get(wiki_home)
    def decode_content(r,encoding): 
        return (r.content.decode(encoding)) 
    contents = decode_content(response,encoding_check(response)) 
    soup = BeautifulSoup(contents, 'html.parser')
    txt_dump=soup.text
    text_list=[] #Empty list 
        for d in soup.find_all('div'): 
            if (d.get('id')=='mp-otd'): 
                for i in d.find_all('ul'): 
                    text_list.append(i.text)
    data = ''' 
<person> 
  <name>Dave</name> 
  <surname>Piccardo</surname> 
  <phone type="intl"> 
     +1 742 101 4456 
   </phone> 
   <email hide="yes"> 
   dave.p@gmail.com</email> 
</person>''' 
    tree = ET.fromstring(data)
    return tree.find('surname').text == x

# %%
def test_exercise_88_3(x) -> bool:
    import requests 
    import xml.etree.ElementTree as ET
    from bs4 import BeautifulSoup 
    wiki_home = "https://en.wikipedia.org/wiki/Main_Page"
    response = requests.get(wiki_home)
    def decode_content(r,encoding): 
        return (r.content.decode(encoding)) 
    contents = decode_content(response,encoding_check(response)) 
    soup = BeautifulSoup(contents, 'html.parser')
    txt_dump=soup.text
    text_list=[] #Empty list 
        for d in soup.find_all('div'): 
            if (d.get('id')=='mp-otd'): 
                for i in d.find_all('ul'): 
                    text_list.append(i.text)
    data = ''' 
<person> 
  <name>Dave</name> 
  <surname>Piccardo</surname> 
  <phone type="intl"> 
     +1 742 101 4456 
   </phone> 
   <email hide="yes"> 
   dave.p@gmail.com</email> 
</person>''' 
    tree = ET.fromstring(data)
    return tree.find('phone').text.strip() == x

# %%
def test_exercise_88_4a(x) -> bool:
    import requests 
    import xml.etree.ElementTree as ET
    from bs4 import BeautifulSoup 
    wiki_home = "https://en.wikipedia.org/wiki/Main_Page"
    response = requests.get(wiki_home)
    def decode_content(r,encoding): 
        return (r.content.decode(encoding)) 
    contents = decode_content(response,encoding_check(response)) 
    soup = BeautifulSoup(contents, 'html.parser')
    txt_dump=soup.text
    text_list=[] #Empty list 
        for d in soup.find_all('div'): 
            if (d.get('id')=='mp-otd'): 
                for i in d.find_all('ul'): 
                    text_list.append(i.text)
    data = ''' 
<person> 
  <name>Dave</name> 
  <surname>Piccardo</surname> 
  <phone type="intl"> 
     +1 742 101 4456 
   </phone> 
   <email hide="yes"> 
   dave.p@gmail.com</email> 
</person>''' 
    tree = ET.fromstring(data)
    return tree.find('email').get('hide') == x

# %%
def test_exercise_88_4b(x) -> bool:
    import requests 
    import xml.etree.ElementTree as ET
    from bs4 import BeautifulSoup 
    wiki_home = "https://en.wikipedia.org/wiki/Main_Page"
    response = requests.get(wiki_home)
    def decode_content(r,encoding): 
        return (r.content.decode(encoding)) 
    contents = decode_content(response,encoding_check(response)) 
    soup = BeautifulSoup(contents, 'html.parser')
    txt_dump=soup.text
    text_list=[] #Empty list 
        for d in soup.find_all('div'): 
            if (d.get('id')=='mp-otd'): 
                for i in d.find_all('ul'): 
                    text_list.append(i.text)
    data = ''' 
<person> 
  <name>Dave</name> 
  <surname>Piccardo</surname> 
  <phone type="intl"> 
     +1 742 101 4456 
   </phone> 
   <email hide="yes"> 
   dave.p@gmail.com</email> 
</person>''' 
    tree = ET.fromstring(data)
    return tree.find('email').text.strip() == x
