# %% [markdown]
# 1. Import random library

# %%
import random

# %% [markdown]
# 2. Use the randint function to generate random integers and add them to a list

# %%
list_1 = [random.randint(0, 30) for x in range (0, 100)] 
list_1
# Out:
# [28,
#  8,
#  21,
#  9,
#  29,
#  29,
#  23,
#  16,
#  3,
#  16,
#  23,
#  19,
#  25,
#  13,
#  5,
#  16,
#  19,
#  29,
#  12,
#  25,
#  7,
#  22,
#  19,
#  14,
#  5,
#  2,
#  20,
#  27,
#  9,
#  16,
#  3,
#  8,
#  20,
#  29,
#  11,
#  13,
#  10,
#  23,
#  4,
#  11,
#  3,
#  4,
#  7,
#  14,
#  18,
#  23,
#  25,
#  16,
#  24,
#  21,
#  27,
#  17,
#  30,
#  3,
#  17,
#  22,
#  2,
#  5,
#  6,
#  4,
#  0,
#  13,
#  10,
#  28,
#  17,
#  27,
#  10,
#  18,
#  25,
#  1,
#  22,
#  28,
#  28,
#  28,
#  15,
#  10,
#  5,
#  30,
#  26,
#  5,
#  22,
#  2,
#  23,
#  10,
#  19,
#  18,
#  24,
#  9,
#  22,
#  2,
#  26,
#  15,
#  23,
#  13,
#  2,
#  1,
#  18,
#  12,
#  23,
#  25]

# %%
list_2 = [x**2 for x in list_1]
list_2
# Out:
# [784,
#  64,
#  441,
#  81,
#  841,
#  841,
#  529,
#  256,
#  9,
#  256,
#  529,
#  361,
#  625,
#  169,
#  25,
#  256,
#  361,
#  841,
#  144,
#  625,
#  49,
#  484,
#  361,
#  196,
#  25,
#  4,
#  400,
#  729,
#  81,
#  256,
#  9,
#  64,
#  400,
#  841,
#  121,
#  169,
#  100,
#  529,
#  16,
#  121,
#  9,
#  16,
#  49,
#  196,
#  324,
#  529,
#  625,
#  256,
#  576,
#  441,
#  729,
#  289,
#  900,
#  9,
#  289,
#  484,
#  4,
#  25,
#  36,
#  16,
#  0,
#  169,
#  100,
#  784,
#  289,
#  729,
#  100,
#  324,
#  625,
#  1,
#  484,
#  784,
#  784,
#  784,
#  225,
#  100,
#  25,
#  900,
#  676,
#  25,
#  484,
#  4,
#  529,
#  100,
#  361,
#  324,
#  576,
#  81,
#  484,
#  4,
#  676,
#  225,
#  529,
#  169,
#  4,
#  1,
#  324,
#  144,
#  529,
#  625]

# %%
import math 
list_2 = [math.log(x,10) for x in list_2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5bd757d32509> in <module>
#       1 import math
# ----> 2 list_2 = [math.log(x,10) for x in list_2]
#
# <ipython-input-7-5bd757d32509> in <listcomp>(.0)
#       1 import math
# ----> 2 list_2 = [math.log(x,10) for x in list_2]
#
# ValueError: math domain error
