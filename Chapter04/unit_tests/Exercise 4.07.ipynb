# %%
def test_exercise54_1a(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    df_missing = df = pd.read_excel("../Sample - Superstore.xls") 
    df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    return df_1.equals(x)

# %%
def test_exercise54_1b(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    df_missing = df = pd.read_excel("../Sample - Superstore.xls") 
    df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    return df_2.equals(x)

# %%
def test_exercise54_1c(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    df_missing = df = pd.read_excel("../Sample - Superstore.xls") 
    df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    return df_3.equals(x)

# %%
def test_exercise54_2(x) -> bool:
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    df_missing = df = pd.read_excel("../Sample - Superstore.xls") 
    df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 
    df = pd.concat([df_1,df_2,df_3], axis=1) 
    return df.equals(x)
