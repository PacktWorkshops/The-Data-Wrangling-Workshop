# %% [markdown]
# 0. load dataset

# %%
import numpy as np 

import pandas as pd 

import matplotlib.pyplot as plt 

df = pd.read_excel("Sample - Superstore.xls") 

df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# 1. Sample 4 records each to create three DataFrames at random from the original sales dataset

# %%
df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 

df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 

df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4)

# %%
df_cat1 = pd.concat([df_1,df_2,df_3], axis=0) 

df_cat1
# Out:
#           Customer Name           State     Sales    Profit
# 684      Grant Thornton  North Carolina   167.440   14.6510
# 2325      Brendan Murry        New York    79.872   29.9520
# 6525    Chad Cunningham    Pennsylvania     5.715   -4.7625
# 9069       Becky Martin      Washington    65.940   30.9918
# 4926      Mary O'Rourke        Illinois    91.275  -67.5435
# 4557  Natalie DeCherney         Arizona     8.559   -6.5619
# 3556      Clay Cheatham      California    45.360   21.7728
# 5397       Matt Connell      California    39.000   11.3100
# 6075       Fred Hopkins      California   270.620    2.7062
# 9234       Lena Radford      California  1091.168   68.1980
# 2987      Julia Barnett         Georgia  1267.650  152.1180
# 3777      Julia Barnett      California   665.880  106.5408

# %%
df_cat2 = pd.concat([df_1,df_2,df_3], axis=1) 

df_cat2
# Out:
#         Customer Name           State    Sales   Profit      Customer Name  \
# 684    Grant Thornton  North Carolina  167.440  14.6510                NaN
# 2325    Brendan Murry        New York   79.872  29.9520                NaN
# 2987              NaN             NaN      NaN      NaN                NaN
# 3556              NaN             NaN      NaN      NaN      Clay Cheatham
# 3777              NaN             NaN      NaN      NaN                NaN
# 4557              NaN             NaN      NaN      NaN  Natalie DeCherney
# 4926              NaN             NaN      NaN      NaN      Mary O'Rourke
# 5397              NaN             NaN      NaN      NaN       Matt Connell
# 6075              NaN             NaN      NaN      NaN                NaN
# 6525  Chad Cunningham    Pennsylvania    5.715  -4.7625                NaN
# 9069     Becky Martin      Washington   65.940  30.9918                NaN
# 9234              NaN             NaN      NaN      NaN                NaN
#
#            State   Sales   Profit  Customer Name       State     Sales  \
# 684          NaN     NaN      NaN            NaN         NaN       NaN
# 2325         NaN     NaN      NaN            NaN         NaN       NaN
# 2987         NaN     NaN      NaN  Julia Barnett     Georgia  1267.650
# 3556  California  45.360  21.7728            NaN         NaN       NaN
# 3777         NaN     NaN      NaN  Julia Barnett  California   665.880
# 4557     Arizona   8.559  -6.5619            NaN         NaN       NaN
# 4926    Illinois  91.275 -67.5435            NaN         NaN       NaN
# 5397  California  39.000  11.3100            NaN         NaN       NaN
# 6075         NaN     NaN      NaN   Fred Hopkins  California   270.620
# 6525         NaN     NaN      NaN            NaN         NaN       NaN
# 9069         NaN     NaN      NaN            NaN         NaN       NaN
# 9234         NaN     NaN      NaN   Lena Radford  California  1091.168
#
#         Profit
# 684        NaN
# 2325       NaN
# 2987  152.1180
# 3556       NaN
# 3777  106.5408
# 4557       NaN
# 4926       NaN
# 5397       NaN
# 6075    2.7062
# 6525       NaN
# 9069       NaN
# 9234   68.1980
